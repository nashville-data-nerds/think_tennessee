# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from textwrap import wrap

# %% [markdown]
# I am working on creating figure 2.3 from the Wisconsin report https://www.cows.org/_data/documents/1933.pdf

# %%
df = pd.read_csv('/Users/daniell2/Desktop/Data_Specialization/ThinkTN/epi_labor_force_data_raw.csv')
# Out:
# Female          65
# All             65
# Young           65
# Other           65
# Old             65
# High school     65
# Male            65
# Some college    65
# Hispanic        65
# White           65
# Black           65
# API             65
# Less than HS    65
# Bachelors       65
# Prime age       65
# Name: categ, dtype: int64

# %% [markdown]
# Selecting TN and Employmnet types I am interest in.

# %%
tn = df[['categ','Nemp18', 'Nunemp18','Nlong18','Npt18']][(df.geo=='Tennessee')]
tn.head(2)
# Out:
#     categ        Nemp18    Nunemp18    Nlong18        Npt18
# 45    All  13521.482470  492.606770  63.683433  2783.428089
# 110  Male   7223.008328  236.947212  26.334690  1108.206083

# %% [markdown]
# I thought I would start off my creating a stacked bar graph (stacking employement type). After I worked that out, I was going to create them using different categories and generate several figures (e.g., by gender, by education).
#
# I found a guide that should work for my purposes, but I keep getting an error: TypeError: only size-1 arrays can be converted to Python scalars.
#
# Any suggestions?

# %%
category =   tn.iloc[:,0]
Employed =   tn.iloc[:,1]
Unemployed = tn.iloc[:,2]
Long_term =  tn.iloc[:,3]
Part_time =  tn.iloc[:,4]

Unemployed.head()

indx = np.arange(len(tn))

plt.figure(figsize=(10,7))

graphEmp =  plt.bar(x= indx, height=Employed, width=0.2)
graphUnEm = plt.bar(x= indx, height=Unemployed, width=0.2, bottom=Employed)
graphLT =   plt.bar(x= indx, height=Long_term, width=0.2)
graphPT =   plt.bar(x= indx, height=Part_time, width=0.2, bottom=Long_term)

plt.xlabel('category')
plt.ylabel('Numbers')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-d5f4714cfdce> in <module>
#      12
#      13 graphEmp =  plt.bar(x= indx, height=Employed, width=0.2)
# ---> 14 graphUnEm = plt.bar(x= indx, height=Unemployed, width=0.2, bottom=Employed)
#      15 graphLT =   plt.bar(x= indx, height=Long_term, width=0.2)
#      16 graphPT =   plt.bar(x= indx, height=Part_time, width=0.2, bottom=Long_term)
#
# ~/anaconda3/envs/think_tn/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# ~/anaconda3/envs/think_tn/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# I think stacked would look better; however, I could produce them side by side.

# %%
ax = tn[['Nemp18', 'Nunemp18','Nlong18','Npt18']].plot(kind='bar', title='Employment',
                                                      figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("X axis", fontsize=12)
ax.set_ylabel("Number", fontsize=12)
plt.show()
